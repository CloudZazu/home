# %%
text = """b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  0 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.semaphore_tracker import main;main(7)\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork\njenkins      50     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork\njenkins      87     50  0 01:16 ?        00:00:00      |   |   \\_ fexp\njenkins      51     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=11) --multiprocessing-fork\njenkins     217     51  0 01:17 ?        00:00:00      |   |   \\_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00      |   |       \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00      |   |       \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      |   |           \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      |   |           \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      |   |           \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      |   |           \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      |   |           \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      |   |           \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      |   |           \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      |   |           \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins      52     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=12) --multiprocessing-fork\njenkins      91     52  0 01:16 ?        00:00:00      |   |   \\_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/bigrow_return_transaction_line_mem_load.tpt tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6 -u TdpId='alder', UserName='tqst_etl_bigrow_user', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_bigrow_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitptbigrow_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_bigrow_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10\njenkins      92     91  0 01:16 ?        00:00:00      |   |       \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0\njenkins     102     91  0 01:16 ?        00:00:00      |   |       \\_ ptmexec 0x00000003\njenkins     103    102  0 01:16 ?        00:00:00      |   |           \\_ ptmgts Group Server\njenkins     104    102  0 01:16 ?        00:00:00      |   |           \\_ ptmtims Timer Server\njenkins     105    102  0 01:16 ?        00:00:00      |   |           \\_ twbmdlgr\njenkins     106    102  0 01:16 ?        00:00:00      |   |           \\_ planexecutor -c 100\njenkins     107    102  0 01:16 ?        00:00:00      |   |           \\_ ptmcmd Command Processor\njenkins     110    102  0 01:16 ?        00:00:00      |   |           \\_ coordinator\njenkins     111    102  7 01:16 ?        00:00:04      |   |           \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     112    102 14 01:16 ?        00:00:08      |   |           \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins     239     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\n"
Removing workload pid: 49
Done with workload pid: 49
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  0 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.semaphore_tracker import main;main(7)\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork\njenkins      50     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork\njenkins      87     50  0 01:16 ?        00:00:00      |   |   \\_ fexp\njenkins      51     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=11) --multiprocessing-fork\njenkins     217     51  0 01:17 ?        00:00:00      |   |   \\_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00      |   |       \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00      |   |       \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      |   |           \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      |   |           \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      |   |           \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      |   |           \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      |   |           \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      |   |           \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      |   |           \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      |   |           \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins      52     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=12) --multiprocessing-fork\njenkins      91     52  0 01:16 ?        00:00:00      |   |   \\_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/bigrow_return_transaction_line_mem_load.tpt tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6 -u TdpId='alder', UserName='tqst_etl_bigrow_user', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_bigrow_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitptbigrow_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_bigrow_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10\njenkins      92     91  0 01:16 ?        00:00:00      |   |       \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0\njenkins     102     91  0 01:16 ?        00:00:00      |   |       \\_ ptmexec 0x00000003\njenkins     103    102  0 01:16 ?        00:00:00      |   |           \\_ ptmgts Group Server\njenkins     104    102  0 01:16 ?        00:00:00      |   |           \\_ ptmtims Timer Server\njenkins     105    102  0 01:16 ?        00:00:00      |   |           \\_ twbmdlgr\njenkins     106    102  0 01:16 ?        00:00:00      |   |           \\_ planexecutor -c 100\njenkins     107    102  0 01:16 ?        00:00:00      |   |           \\_ ptmcmd Command Processor\njenkins     110    102  0 01:16 ?        00:00:00      |   |           \\_ coordinator\njenkins     111    102  7 01:16 ?        00:00:04      |   |           \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     112    102 14 01:16 ?        00:00:08      |   |           \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins     240     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\n"
Removing workload pid: 50
Done with workload pid: 50
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  0 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.semaphore_tracker import main;main(7)\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork\njenkins      50     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      51     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=11) --multiprocessing-fork\njenkins     217     51  0 01:17 ?        00:00:00      |   |   \\_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00      |   |       \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00      |   |       \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      |   |           \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      |   |           \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      |   |           \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      |   |           \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      |   |           \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      |   |           \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      |   |           \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      |   |           \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins      52     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=12) --multiprocessing-fork\njenkins      91     52  0 01:16 ?        00:00:00      |   |   \\_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/bigrow_return_transaction_line_mem_load.tpt tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6 -u TdpId='alder', UserName='tqst_etl_bigrow_user', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_bigrow_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitptbigrow_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_bigrow_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10\njenkins      92     91  0 01:16 ?        00:00:00      |   |       \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0\njenkins     102     91  0 01:16 ?        00:00:00      |   |       \\_ ptmexec 0x00000003\njenkins     103    102  0 01:16 ?        00:00:00      |   |           \\_ ptmgts Group Server\njenkins     104    102  0 01:16 ?        00:00:00      |   |           \\_ ptmtims Timer Server\njenkins     105    102  0 01:16 ?        00:00:00      |   |           \\_ twbmdlgr\njenkins     106    102  0 01:16 ?        00:00:00      |   |           \\_ planexecutor -c 100\njenkins     107    102  0 01:16 ?        00:00:00      |   |           \\_ ptmcmd Command Processor\njenkins     110    102  0 01:16 ?        00:00:00      |   |           \\_ coordinator\njenkins     111    102  7 01:16 ?        00:00:04      |   |           \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     112    102 14 01:16 ?        00:00:08      |   |           \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins     241     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\n"
Removing workload pid: 51
Done with workload pid: 51
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  0 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.semaphore_tracker import main;main(7)\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork\njenkins      50     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      51     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      52     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=12) --multiprocessing-fork\njenkins      91     52  0 01:16 ?        00:00:00      |   |   \\_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/bigrow_return_transaction_line_mem_load.tpt tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6 -u TdpId='alder', UserName='tqst_etl_bigrow_user', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_bigrow_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitptbigrow_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_bigrow_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10\njenkins      92     91  0 01:16 ?        00:00:00      |   |       \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0\njenkins     102     91  0 01:16 ?        00:00:00      |   |       \\_ ptmexec 0x00000003\njenkins     103    102  0 01:16 ?        00:00:00      |   |           \\_ ptmgts Group Server\njenkins     104    102  0 01:16 ?        00:00:00      |   |           \\_ ptmtims Timer Server\njenkins     105    102  0 01:16 ?        00:00:00      |   |           \\_ twbmdlgr\njenkins     106    102  0 01:16 ?        00:00:00      |   |           \\_ planexecutor -c 100\njenkins     107    102  0 01:16 ?        00:00:00      |   |           \\_ ptmcmd Command Processor\njenkins     110    102  0 01:16 ?        00:00:00      |   |           \\_ coordinator\njenkins     111    102  7 01:16 ?        00:00:04      |   |           \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     112    102 14 01:16 ?        00:00:08      |   |           \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins     242     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing workload pid: 52
Done with workload pid: 52
Traceback (most recent call last):
  File "/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/framework/decorators/suite_main.py", line 51, in suite_run_wrapper
    raise SuiteResultError('Some/all workloads failed')
symphony.suite.SuiteResultError: Some/all workloads failed

Some/all workloads failed
Traceback (most recent call last):
  File "./entrypoint.py", line 60, in <module>
    suite().main()
  File "/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/framework/decorators/suite_main.py", line 51, in suite_run_wrapper
    raise SuiteResultError('Some/all workloads failed')
symphony.suite.SuiteResultError: Some/all workloads failed
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.semaphore_tracker import main;main(7)\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork\njenkins     243     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/bigrow_return_transaction_line_mem_load.tpt tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6 -u TdpId='alder', UserName='tqst_etl_bigrow_user', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_bigrow_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitptbigrow_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_bigrow_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10\njenkins      92     91  0 01:16 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0\njenkins     102     91  0 01:16 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     103    102  0 01:16 ?        00:00:00      \\_ ptmgts Group Server\njenkins     104    102  0 01:16 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     105    102  0 01:16 ?        00:00:00      \\_ twbmdlgr\njenkins     106    102  0 01:16 ?        00:00:00      \\_ planexecutor -c 100\njenkins     107    102  0 01:16 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     110    102  0 01:16 ?        00:00:00      \\_ coordinator\njenkins     111    102  7 01:16 ?        00:00:04      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     112    102 14 01:16 ?        00:00:08      \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=41, name='python3', started='01:16:01')
Done with psutil.Process(pid=41, name='python3', started='01:16:01')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork\njenkins     244     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/bigrow_return_transaction_line_mem_load.tpt tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6 -u TdpId='alder', UserName='tqst_etl_bigrow_user', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_bigrow_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitptbigrow_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_bigrow_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10\njenkins      92     91  0 01:16 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0\njenkins     102     91  0 01:16 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     103    102  0 01:16 ?        00:00:00      \\_ ptmgts Group Server\njenkins     104    102  0 01:16 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     105    102  0 01:16 ?        00:00:00      \\_ twbmdlgr\njenkins     106    102  0 01:16 ?        00:00:00      \\_ planexecutor -c 100\njenkins     107    102  0 01:16 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     110    102  0 01:16 ?        00:00:00      \\_ coordinator\njenkins     111    102  7 01:16 ?        00:00:04      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     112    102 14 01:16 ?        00:00:08      \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=42, name='python3', started='01:16:01')
Done with psutil.Process(pid=42, name='python3', started='01:16:01')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     245     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/bigrow_return_transaction_line_mem_load.tpt tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6 -u TdpId='alder', UserName='tqst_etl_bigrow_user', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_bigrow_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitptbigrow_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_bigrow_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10\njenkins      92     91  0 01:16 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0\njenkins     102     91  0 01:16 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     103    102  0 01:16 ?        00:00:00      \\_ ptmgts Group Server\njenkins     104    102  0 01:16 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     105    102  0 01:16 ?        00:00:00      \\_ twbmdlgr\njenkins     106    102  0 01:16 ?        00:00:00      \\_ planexecutor -c 100\njenkins     107    102  0 01:16 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     110    102  0 01:16 ?        00:00:00      \\_ coordinator\njenkins     111    102  7 01:16 ?        00:00:04      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     112    102 14 01:16 ?        00:00:08      \\_ executor -t0 -b 0 -p SELECT_2[0001]\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=91, name='tbuildexe', started='01:16:03')
Done with psutil.Process(pid=91, name='tbuildexe', started='01:16:03')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     246     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0\njenkins     102      1  0 01:16 ?        00:00:00 ptmexec 0x00000003\njenkins     103    102  0 01:16 ?        00:00:00  \\_ ptmgts Group Server\njenkins     105    102  0 01:16 ?        00:00:00  \\_ twbmdlgr\njenkins     112    102 14 01:16 ?        00:00:08  \\_ [executor]\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=92, name='ptmjlgr', started='01:16:03')
Done with psutil.Process(pid=92, name='ptmjlgr', started='01:16:03')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     247     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=102, name='ptmexec', started='01:16:04')
Done with psutil.Process(pid=102, name='ptmexec', started='01:16:04')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     248     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=103, status='terminated')
Done with psutil.Process(pid=103, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     249     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=104, status='terminated')
Done with psutil.Process(pid=104, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     250     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=105, status='terminated')
Done with psutil.Process(pid=105, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     251     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=106, status='terminated')
Done with psutil.Process(pid=106, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     252     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=107, status='terminated')
Done with psutil.Process(pid=107, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     253     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=110, status='terminated')
Done with psutil.Process(pid=110, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     254     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=111, status='terminated')
Done with psutil.Process(pid=111, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     255     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=112, status='terminated')
Done with psutil.Process(pid=112, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     256     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'\njenkins     218    217  0 01:17 ?        00:00:00  \\_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0\njenkins     221    217  0 01:17 ?        00:00:00  \\_ ptmexec 0x00000003\njenkins     222    221  0 01:17 ?        00:00:00      \\_ ptmgts Group Server\njenkins     223    221  0 01:17 ?        00:00:00      \\_ ptmtims Timer Server\njenkins     224    221  0 01:17 ?        00:00:00      \\_ twbmdlgr\njenkins     225    221  0 01:17 ?        00:00:00      \\_ planexecutor -c 100\njenkins     226    221  0 01:17 ?        00:00:00      \\_ ptmcmd Command Processor\njenkins     229    221  0 01:17 ?        00:00:00      \\_ coordinator\njenkins     230    221  6 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p APPLY_1[0001]\njenkins     231    221  0 01:17 ?        00:00:00      \\_ executor -t0 -b 0 -p SELECT_2[0001]\n"
Removing psutil.Process(pid=217, name='tbuildexe', started='01:17:00')
Done with psutil.Process(pid=217, name='tbuildexe', started='01:17:00')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     257     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec]\n"
Removing psutil.Process(pid=218, name='ptmjlgr', started='01:17:00')
Done with psutil.Process(pid=218, name='ptmjlgr', started='01:17:00')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     258     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=221, name='ptmexec', started='01:17:01')
Done with psutil.Process(pid=221, name='ptmexec', started='01:17:01')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     259     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=222, status='terminated')
Done with psutil.Process(pid=222, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     260     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=223, status='terminated')
Done with psutil.Process(pid=223, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     261     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=224, status='terminated')
Done with psutil.Process(pid=224, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     262     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=225, status='terminated')
Done with psutil.Process(pid=225, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     263     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=226, status='terminated')
Done with psutil.Process(pid=226, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     264     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=229, status='terminated')
Done with psutil.Process(pid=229, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     265     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=230, status='terminated')
Done with psutil.Process(pid=230, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     266     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=231, status='terminated')
Done with psutil.Process(pid=231, status='terminated')
b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     179      0  0 01:16 pts/1    00:00:00 bash\njenkins      29      0  0 01:16 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins      30     29  0 01:16 ?        00:00:00  \\_ sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt'; sleep 3; done } & jsc=durable-5cb0b52b72310424b9ba375ec2e5d94c; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt.tmp' '/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/jenkins-result.txt'; wait) >&- 2>&- &\njenkins     237     30  0 01:17 ?        00:00:00  |   \\_ sleep 3\njenkins      31     29  0 01:16 ?        00:00:00  \\_ /bin/bash /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl@tmp/durable-8afcd09a/script.sh\njenkins      33     31  1 01:16 ?        00:00:00      \\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/\njenkins      41     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins      42     33  0 01:16 ?        00:00:00      |   \\_ [python3] <defunct>\njenkins     267     33  0 01:17 ?        00:00:00      |   \\_ ps -aef --forest\njenkins      34     31  0 01:16 ?        00:00:00      \\_ tee /proc/1/fd/1\njenkins       1      0  0 01:15 pts/0    00:00:00 cat\njenkins      87      1  0 01:16 ?        00:00:00 fexp\njenkins      91      1  0 01:16 ?        00:00:00 [tbuildexe] <defunct>\njenkins      92      1  0 01:16 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     102      1  0 01:16 ?        00:00:00 [ptmexec] <defunct>\njenkins     217      1  0 01:17 ?        00:00:00 [tbuildexe] <defunct>\njenkins     218      1  0 01:17 ?        00:00:00 [ptmjlgr] <defunct>\njenkins     221      1  0 01:17 ?        00:00:00 [ptmexec] <defunct>\n"
Removing psutil.Process(pid=87, name='fexp', started='01:16:03')
Done with psutil.Process(pid=87, name='fexp', started='01:16:03')"""

# %%
entrypoint_text = """jenkins      33     31  0 01:16 ?        00:00:00      \_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/
jenkins      41     33  0 01:16 ?        00:00:00      |   \_ /usr/local/bin/python3 -c from multiprocessing.semaphore_tracker import main;main(7)
jenkins      42     33  0 01:16 ?        00:00:00      |   \_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork
jenkins      50     33  0 01:16 ?        00:00:00      |   \_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10) --multiprocessing-fork
jenkins      87     50  0 01:16 ?        00:00:00      |   |   \_ fexp
jenkins      51     33  0 01:16 ?        00:00:00      |   \_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=11) --multiprocessing-fork
jenkins     217     51  0 01:17 ?        00:00:00      |   |   \_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/stream_upsert_return_transaction_line_stream_upsert.tpt tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69 -u TdpId='alder', UserName='sitq_etl_user3', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitpt_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_work_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10, num_row_per_each_stream_insert='100000', num_row_per_each_update_insert='150000', num_row_per_stream_upsert='50000'
jenkins     218    217  0 01:17 ?        00:00:00      |   |       \_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9687d1c8-2e36-47d0-b293-3c8f988e5b69-7.out 0
jenkins     221    217  0 01:17 ?        00:00:00      |   |       \_ ptmexec 0x00000003
jenkins     222    221  0 01:17 ?        00:00:00      |   |           \_ ptmgts Group Server
jenkins     223    221  0 01:17 ?        00:00:00      |   |           \_ ptmtims Timer Server
jenkins     224    221  0 01:17 ?        00:00:00      |   |           \_ twbmdlgr
jenkins     225    221  0 01:17 ?        00:00:00      |   |           \_ planexecutor -c 100
jenkins     226    221  0 01:17 ?        00:00:00      |   |           \_ ptmcmd Command Processor
jenkins     229    221  0 01:17 ?        00:00:00      |   |           \_ coordinator
jenkins     230    221  6 01:17 ?        00:00:00      |   |           \_ executor -t0 -b 0 -p APPLY_1[0001]
jenkins     231    221  0 01:17 ?        00:00:00      |   |           \_ executor -t0 -b 0 -p SELECT_2[0001]
jenkins      52     33  0 01:16 ?        00:00:00      |   \_ /usr/local/bin/python3 -c from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=12) --multiprocessing-fork
jenkins      91     52  0 01:16 ?        00:00:00      |   |   \_ tbuildexe -R 100 -f /home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/sql/bigrow_return_transaction_line_mem_load.tpt tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6 -u TdpId='alder', UserName='tqst_etl_bigrow_user', DirectoryPath='/home/jenkins/agent/workspace/Test_Dev/dm186069/sdt25548/sit_etl/suites/sit_etl/data', FileName='return_transaction_line_bigrow_clone_1.data', tracelevel='none', query_band='ApplicationName=sit_etl;appVersion=1.0;testName=nopitptbigrow_1;JobID=20200407011519000680;blockcompression=true;TVSTEMPERATURE=default;TVSMIGRATION=default;', target_database='tqst_etl_bigrow_db', target_nopi_table='return_transaction_line_nopi1', target_pi_table='return_transaction_line_pi1', num_row_to_load_for_return_transaction_line='100000000', enable_data_encryption='ON', nbr_load_sessions=10
jenkins      92     91  0 01:16 ?        00:00:00      |   |       \_ JobLogger /opt/teradata/client/16.20/tbuild/logs/tpt_9ba7e056-7bd7-4c97-8382-cf275eea2ea6-2.out 0
jenkins     102     91  0 01:16 ?        00:00:00      |   |       \_ ptmexec 0x00000003
jenkins     103    102  0 01:16 ?        00:00:00      |   |           \_ ptmgts Group Server
jenkins     104    102  0 01:16 ?        00:00:00      |   |           \_ ptmtims Timer Server
jenkins     105    102  0 01:16 ?        00:00:00      |   |           \_ twbmdlgr
jenkins     106    102  0 01:16 ?        00:00:00      |   |           \_ planexecutor -c 100
jenkins     107    102  0 01:16 ?        00:00:00      |   |           \_ ptmcmd Command Processor
jenkins     110    102  0 01:16 ?        00:00:00      |   |           \_ coordinator
jenkins     111    102  7 01:16 ?        00:00:04      |   |           \_ executor -t0 -b 0 -p APPLY_1[0001]
jenkins     112    102 14 01:16 ?        00:00:08      |   |           \_ executor -t0 -b 0 -p SELECT_2[0001]
jenkins     240     33  0 01:17 ?        00:00:00      |   \_ ps -aef --forest
jenkins      34     31  0 01:16 ?        00:00:00      \_ tee /proc/1/fd/1"""

# %%
entrypoint_lines = entrypoint_text.split('\n')

# %%
header = "UID         PID   PPID  C STIME TTY          TIME CMD"
columns = header.split()
print(columns)
# Out:
# ['UID', 'PID', 'PPID', 'C', 'STIME', 'TTY', 'TIME', 'CMD']

# %%
data = list()

for raw_line in entrypoint_lines:
    values = raw_line.split()
    
    line_mapping = dict()
    for i in range(len(columns)):
        key = columns[i]
        if i == len(columns)-1:
            line_mapping[key] = ' '.join(values[i:])
        else:
            line_mapping[key] = values[i]
            
    data.append(line_mapping)
    
print(data[0])
# Out:
# {'UID': 'jenkins', 'PID': '33', 'PPID': '31', 'C': '0', 'STIME': '01:16', 'TTY': '?', 'TIME': '00:00:00', 'CMD': '\\_ python3 ./entrypoint.py --dbs_name=alder --production_system=false --root_password=Sit4me123! --ssh_allowed=true --dbc_user=dbc --dbc_password=dbc --parent_db=dbc --action_on_error=stoptestnow --run_setup=false --run_test=true --run_cleanup=false --run_iteration=1 --run_duration=0 --suite_name=sit_etl --database_name=TQST_etl --script_path=suites/sit_etl --pi_sa_clones=1 --nopi_sa_clones=1 --nopi_tpt_clones=1 --bigrow_nopi_tpt_clones=1 --enable_blc=true --base_row_percent=100 --bigrow_base_row_percent=10 --nbr_load_sessions=10 --tvs_temp=default --tvs_migrate=default --tpt_trace_level=none --enable_data_encryption=true --run_checktable=false --retry_errors=9134 --max_retry=3 --retry_delay=15 --collect_run_details=false --debug_mode=true --smoke_test=false --run_id=20200407011519000680 --output_path=/var/log/workload/20200407011519000680/sit_etl/'}

# %%
pids = [int(item['PID']) for item in data]
ppids = [int(item['PPID']) for item in data]

def print_list_horizontally(arr):
    for item in arr:
        print(item, end=' ')
        
for arr in [pids, ppids]:
    print_list_horizontally(arr)
    print('\n')
# Out:
# 33 41 42 50 87 51 217 218 221 222 223 224 225 226 229 230 231 52 91 92 102 103 104 105 106 107 110 111 112 240 34
#
# 31 33 33 33 50 33 51 217 217 221 221 221 221 221 221 221 221 33 52 91 91 102 102 102 102 102 102 102 102 33 31

# %%
import collections

ppid_pid_mapping = collections.defaultdict(list)

assert len(pids) == len(ppids)

for i in range(len(pids)):
    key = ppids[i]
    value = pids[i]
    
    ppid_pid_mapping[key].append(value)

# %%
import json

print(json.dumps(ppid_pid_mapping))
# Out:
# {"31": [33, 34], "33": [41, 42, 50, 51, 52, 240], "50": [87], "51": [217], "217": [218, 221], "221": [222, 223, 224, 225, 226, 229, 230, 231], "52": [91], "91": [92, 102], "102": [103, 104, 105, 106, 107, 110, 111, 112]}

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.children = list()
        
    def add(self, value):
        self.children.append(value)
    
vertice_mapping = dict()

for parent, children in ppid_pid_mapping.items():
    node_ids = [parent] + children
    for node_id in node_ids:
        if node_id not in vertice_mapping:
            vertice_mapping[node_id] = Node(node_id)

for parent, children in ppid_pid_mapping.items():
    for child in children:
        vertice_mapping[parent].add(vertice_mapping[child])

# %%
print([node.children for node in vertice_mapping.values()])
# Out:
# [[<__main__.Node object at 0x10621d1d0>, <__main__.Node object at 0x10621de90>], [<__main__.Node object at 0x10621d610>, <__main__.Node object at 0x10621d850>, <__main__.Node object at 0x10621df50>, <__main__.Node object at 0x10621db10>, <__main__.Node object at 0x10621d650>, <__main__.Node object at 0x10621df90>], [], [], [], [<__main__.Node object at 0x10621dcd0>], [<__main__.Node object at 0x10621db90>], [<__main__.Node object at 0x10621dd50>], [], [], [<__main__.Node object at 0x10621d7d0>, <__main__.Node object at 0x10621d250>], [], [<__main__.Node object at 0x10621d590>, <__main__.Node object at 0x10621d350>, <__main__.Node object at 0x10621dc90>, <__main__.Node object at 0x10621d310>, <__main__.Node object at 0x10621d690>, <__main__.Node object at 0x10621d750>, <__main__.Node object at 0x10621ded0>, <__main__.Node object at 0x10621dbd0>], [], [], [], [], [], [], [], [], [<__main__.Node object at 0x10621dd90>, <__main__.Node object at 0x10621dd10>], [], [<__main__.Node object a
# ...

# %%
def bfs(node):
    
    queue = collections.deque([node])
    
    while queue:
        
        print([node.value for node in queue])
        
        for i in range(len(queue)):
            node = queue.popleft()

            if node.children:
                for child in node.children:
                    queue.append(child)
                    
        if queue:
            print('|')

target_node = vertice_mapping[51]
bfs(target_node)
# Out:
# [51]
# |
# [217]
# |
# [218, 221]
# |
# [222, 223, 224, 225, 226, 229, 230, 231]

# %%
from treelib import Node, Tree

tree = Tree()

def bfs_tree(node):
    
    queue = collections.deque([node])
    
    visited = set()
    
    while queue:
        for i in range(len(queue)):
            node = queue.popleft()
            
            if node.value not in visited:
                visited.add(node.value)
                tree.create_node(node.value, node.value)
            
            if node.children:
                for child in node.children:
                    if child.value not in visited:
                        visited.add(child.value)
                        tree.create_node(child.value, child.value, parent=node.value)
                    queue.append(child)
                    
    tree.show()

target_node = vertice_mapping[51]
bfs_tree(target_node)
# Out:
# 51
# └── 217
#     ├── 218
#     └── 221
#         ├── 222
#         ├── 223
#         ├── 224
#         ├── 225
#         ├── 226
#         ├── 229
#         ├── 230
#         └── 231

# %%
""" 
    Psuedo-code for loading the process dump and determining problematic routes
    # Convert data to a processable format
    # Look for entrypoint target node - use this as an origin point
    # Populate all numbers associated with that path
    # Per seq, show tree or trees - Showcases deletion sequence
"""
import pandas

DUMP_FILENAME = 'process_dump.csv'

df = pandas.read_csv(DUMP_FILENAME)
df.head()
# Out:
#                                         process_info  seq  target_pid  \
# 0  [{'username': 'jenkins', 'ppid': 0, 'cmdline':...    0          49
# 1  [{'username': 'jenkins', 'ppid': 0, 'cmdline':...    1          49
# 2  [{'username': 'jenkins', 'ppid': 0, 'cmdline':...    2          50
# 3  [{'username': 'jenkins', 'ppid': 0, 'cmdline':...    3          50
# 4  [{'username': 'jenkins', 'ppid': 0, 'cmdline':...    4          51
#
#    prior_terminate  terminate_complete
# 0             True               False
# 1             True                True
# 2             True               False
# 3             True                True
# 4             True               False

# %%
import ast

process_entries = df['process_info'].tolist()
rendered_process_entries = [ast.literal_eval(process_entries[i]) for i in range(len(process_entries))]

# %%
first_entry = rendered_process_entries[0]
print(first_entry[0].keys())
# Out:
# dict_keys(['username', 'ppid', 'cmdline', 'status', 'name', 'pid'])

# %%
import time
import sys


animation = "|/-\\"

for i in range(100):
    time.sleep(0.1)
    sys.stdout.write("\r" + animation[i % len(animation)])
    sys.stdout.flush()
print "End!"

# %%
import json
import time
import sys

for i in range(1, len(rendered_process_entries)+1):
    final_entry = rendered_process_entries[-i]
    
    buffer = list()
    
    for row in final_entry:
        if row['pid'] in [41,42] and row['status'] != 'zombie':
            buffer.append(row)
            
            if len(buffer) >= 2:
                time.sleep(1)
                for found_row in buffer:
                    sys.stdout.write(str(found_row)) # force buffer flush
                sys.stdout.write('\r')
                sys.stdout.flush()
# Out:
# {'username': 'jenkins', 'ppid': 34, 'cmdline': ['/usr/local/bin/python3', '-c', 'from multiprocessing.semaphore_tracker import main;main(7)'], 'status': 'sleeping', 'name': 'python3', 'pid': 41}{'username': 'jenkins', 'ppid': 34, 'cmdline': ['/usr/local/bin/python3', '-c', 'from multiprocessing.spawn import spawn_main; spawn_main(tracker_fd=8, pipe_handle=10)', '--multiprocessing-fork'], 'status': 'sleeping', 'name': 'python3', 'pid': 42}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-fb0152c9dc50> in <module>
#      13
#      14             if len(buffer) >= 2:
# ---> 15                 time.sleep(1)
#      16                 for found_row in buffer:
#      17                     sys.stdout.write(str(found_row)) # force buffer flush
#
# KeyboardInterrupt:

# %%
# Get unique statuses

statuses = set()

for process_history in rendered_process_entries:
    for entry in process_history:
        statuses.add(entry['status'])
    
print(statuses)
# Out:
# {'zombie', 'running', 'sleeping'}

# %%
# Detect entrypoint cmdline

def find_entrypoint_pid(rendered_process_entries):
    for process_history in rendered_process_entries:
        for entry in process_history:
            cmd = entry['cmdline']

            for word in cmd:
                try:
                    if 'entrypoint' in word:
                        return entry['pid']
                except Exception as e:
                    print(f'Warning: {e}')
    return False
                
entrypoint_pid = find_entrypoint_pid(rendered_process_entries)

# %%
cmdlines
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1ba9c6eb4f00> in <module>
# ----> 1 cmdlines
#
# NameError: name 'cmdlines' is not defined

# %%
data = rendered_process_entries

pids = [[int(item['pid']) for item in process_history] for process_history in data]
ppids = [[int(item['ppid']) for item in process_history] for process_history in data]

# %%
import collections

ppid_pid_mapping = collections.defaultdict(list)

pids = pids[0]
ppids = ppids[0]

assert len(pids) == len(ppids)

for i in range(len(pids)):
    key = ppids[i]
    value = pids[i]
    
    ppid_pid_mapping[key].append(value)

# %%
ppid_pid_mapping

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.children = list()
        
    def add(self, value):
        self.children.append(value)
    
vertice_mapping = dict()

for parent, children in ppid_pid_mapping.items():
    node_ids = [parent] + children
    for node_id in node_ids:
        if node_id not in vertice_mapping:
            vertice_mapping[node_id] = Node(node_id)

for parent, children in ppid_pid_mapping.items():
    for child in children:
        vertice_mapping[parent].add(vertice_mapping[child])

# %%
from treelib import Node, Tree

tree = Tree()

def bfs_tree(node):
    
    queue = collections.deque([node])
    
    visited = set()
    cnt = 0
    while queue:
        for i in range(len(queue)):
            node = queue.popleft()
            cnt += 1
            if node.value not in visited:
                visited.add(node.value)
                tree.create_node(node.value, node.value)
            
            if node.children:
                for child in node.children:
                    if child.value not in visited:
                        visited.add(child.value)
                        tree.create_node(child.value, child.value, parent=node.value)
                    queue.append(child)
    
    print(f'Number of nodes: {cnt}')
    tree.show()

target_node = entrypoint_pid
target_node = vertice_mapping[target_node]
bfs_tree(target_node)

# %%
import matplotlib.pyplot as plt
import networkx as nx

# BFS from parent node 
parent = dr_num # dr var from upper cell

G = nx.Graph()
G.add_nodes_from([parent])
G.add_nodes_from(visited)
G.add_edges_from(routes)

plt.figure(1, figsize=(18,18))
#tree = nx.bfs_tree(G, source=parent)
nx.draw_spring(G, with_labels=True, font_weight='bold')
#plt.savefig(f'{parent}_graph.png', format="PNG")
plt.show()

# %%
process_content = """Remaining processes: [psutil.Process(pid=948, name='python3', started='03:18:39'), psutil.Process(pid=949, name='python3', started='03:18:39'), psutil.Process(pid=986, name='python3', started='03:18:40'), psutil.Process(pid=988, name='python3', started='03:18:40'), psutil.Process(pid=1030, name='python3', started='03:18:41'), psutil.Process(pid=985, name='python3', started='03:18:40'), psutil.Process(pid=987, name='python3', started='03:18:40'), psutil.Process(pid=1006, name='python3', started='03:18:41'), psutil.Process(pid=981, name='python3', started='03:18:40'), psutil.Process(pid=982, name='python3', started='03:18:40'), psutil.Process(pid=1018, name='python3', started='03:18:41'), psutil.Process(pid=979, name='python3', started='03:18:40'), psutil.Process(pid=980, name='python3', started='03:18:40'), psutil.Process(pid=1024, name='python3', started='03:18:41')]
"""

# %%
import re

ids = re.findall('pid=(\d*)', process_content)
ids = [int(_id) for _id in ids]
ids.sort()

# %%
termination_content = """
Prior to termination pid: 956
Terminated pid: 956
Prior to termination pid: 957
Terminated pid: 957
Prior to termination pid: 958
Terminated pid: 958
Prior to termination pid: 959
Terminated pid: 959
Prior to termination pid: 960
Terminated pid: 960
Prior to termination pid: 961
Terminated pid: 961
Traceback (most recent call last):
  File "/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat/framework/decorators/suite_main.py", line 51, in suite_run_wrapper
    raise SuiteResultError('Some/all workloads failed')
symphony.suite.SuiteResultError: Some/all workloads failed

Some/all workloads failed
===Running after test data collection===
===Calling edge analytics for once===
2020-04-15 03:22:47,952 - teradata.udaexec - ERROR - Uncaught exception
Traceback (most recent call last):
  File "./entrypoint.py", line 60, in <module>
    suite().main()
  File "/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat/framework/decorators/suite_main.py", line 51, in suite_run_wrapper
    raise SuiteResultError('Some/all workloads failed')
symphony.suite.SuiteResultError: Some/all workloads failed
Traceback (most recent call last):
  File "./entrypoint.py", line 60, in <module>
    suite().main()
  File "/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat/framework/decorators/suite_main.py", line 51, in suite_run_wrapper
    raise SuiteResultError('Some/all workloads failed')
symphony.suite.SuiteResultError: Some/all workloads failed
Removing psutil.Process(pid=1024, name='python3', started='03:18:41')
Done with psutil.Process(pid=1024, name='python3', started='03:18:41')
Removing psutil.Process(pid=980, name='python3', started='03:18:40')
Done with psutil.Process(pid=980, name='python3', started='03:18:40')
Removing psutil.Process(pid=979, name='python3', started='03:18:40')
Done with psutil.Process(pid=979, name='python3', started='03:18:40')
Removing psutil.Process(pid=1018, name='python3', started='03:18:41')
Done with psutil.Process(pid=1018, name='python3', started='03:18:41')
Removing psutil.Process(pid=982, name='python3', started='03:18:40')
Done with psutil.Process(pid=982, name='python3', started='03:18:40')
Removing psutil.Process(pid=981, name='python3', started='03:18:40')
Done with psutil.Process(pid=981, name='python3', started='03:18:40')
Removing psutil.Process(pid=1006, name='python3', started='03:18:41')
Done with psutil.Process(pid=1006, name='python3', started='03:18:41')
Removing psutil.Process(pid=987, name='python3', started='03:18:40')
Done with psutil.Process(pid=987, name='python3', started='03:18:40')
Removing psutil.Process(pid=985, name='python3', started='03:18:40')
Done with psutil.Process(pid=985, name='python3', started='03:18:40')
Removing psutil.Process(pid=1030, name='python3', started='03:18:41')
Done with psutil.Process(pid=1030, name='python3', started='03:18:41')
Removing psutil.Process(pid=988, name='python3', started='03:18:40')
Done with psutil.Process(pid=988, name='python3', started='03:18:40')
Removing psutil.Process(pid=986, name='python3', started='03:18:40')
Done with psutil.Process(pid=986, name='python3', started='03:18:40')
Removing psutil.Process(pid=949, name='python3', started='03:18:39')
Done with psutil.Process(pid=949, name='python3', started='03:18:39')
Removing psutil.Process(pid=948, name='python3', started='03:18:39')
Done with psutil.Process(pid=948, name='python3', started='03:18:39')"""

# %%
pid_regex = ['pid: (\d*)', 'pid=(\d*)']

terminated_pids = list()
for pattern in pid_regex:
    pids = re.findall(pattern, termination_content)
    terminated_pids.extend([int(pid) for pid in pids])

terminated_pids = sorted(set(terminated_pids))

# %%
ids
# Out:
# [948, 949, 979, 980, 981, 982, 985, 986, 987, 988, 1006, 1018, 1024, 1030]

# %%
print(all_pids)
# Out:
# [948, 949, 956, 957, 958, 959, 960, 961, 979, 980, 981, 982, 985, 986, 987, 988, 1006, 1018, 1024, 1030]

# %%
terminated_pids = set(terminated_pids)
ids = set(ids)

# %%
ids-terminated_pids
# Out:
# set()

# %%
terminated_pids-ids
# Out:
# {956, 957, 958, 959, 960, 961}

# %%
with open('kernel_process_dump.csv') as file:
    content = file.read()

# %%
lines = content.split('\n')
lines = [line for line in lines if line != '' and 'Current sequence' not in line]

print(str(lines[0]))
# Out:
# b"UID         PID   PPID  C STIME TTY          TIME CMD\njenkins     154      0  0 01:51 pts/1    00:00:00 bash\njenkins      29      0  0 01:49 ?        00:00:00 sh -c ({ while [ -d '/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat@tmp/durable-3ce62332' -a \\! -f '/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat@tmp/durable-3ce62332/jenkins-result.txt' ]; do touch '/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat@tmp/durable-3ce62332/jenkins-log.txt'; sleep 3; done } & jsc=durable-fe9104ba52184e5551b3ea898bb07500; JENKINS_SERVER_COOKIE=$jsc  '/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat@tmp/durable-3ce62332/script.sh' > '/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat@tmp/durable-3ce62332/jenkins-log.txt' 2>&1; echo $? > '/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analytics_pat@tmp/durable-3ce62332/jenkins-result.txt.tmp'; mv '/home/jenkins/agent/workspace/Test_Dev/ah186048/sit_analyti
# ...
